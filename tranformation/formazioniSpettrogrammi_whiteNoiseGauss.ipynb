# %%
import os
from PIL import Image
import numpy as np

def rimuovi_immagini_bianche(cartella, soglia=250):
    """
    Rimuove tutte le immagini bianche dalla cartella specificata.
    
    Argomenti:
    - cartella: percorso della cartella dove si trovano le immagini.
    - soglia: valore della luminosità media oltre la quale l'immagine viene considerata bianca (predefinito 250).
    """
    # Ottieni la lista di file nella cartella
    files = os.listdir(cartella)
    
    # Filtra solo i file immagine (png, jpg, jpeg)
    immagini = [f for f in files if f.endswith(('.png', '.jpg', '.jpeg'))]
    
    for immagine in immagini:
        percorso_immagine = os.path.join(cartella, immagine)
        
        # Carica l'immagine
        try:
            with Image.open(percorso_immagine) as img:
                # Converti l'immagine in scala di grigi
                img_gray = img.convert('L')
                
                # Calcola la luminosità media
                luminosita_media = np.mean(np.array(img_gray))
                
                # Se la luminosità media supera la soglia, elimina l'immagine
                if luminosita_media >= soglia:
                    os.remove(percorso_immagine)
                    print(f"Rimosso: {immagine} (Luminosità media: {luminosita_media})")
        
        except Exception as e:
            print(f"Errore nell'elaborazione dell'immagine {immagine}: {e}")

# Esempio di utilizzo
cartella = '/Users/roberto/Desktop/UNI 3^ ANNO/tesi/spettrogrammiTSLA,KK/spettrogrammi_TSLA'
rimuovi_immagini_bianche(cartella)

# %%
import os
from PIL import Image
import numpy as np

def rimuovi_immagini_bianche(cartella, soglia=245, percentuale_bianchi=0.95):
    """
    Rimuove tutte le immagini prevalentemente bianche dalla cartella specificata.
    
    Argomenti:
    - cartella: percorso della cartella dove si trovano le immagini.
    - soglia: valore della luminosità sopra il quale il pixel viene considerato bianco (predefinito 245).
    - percentuale_bianchi: percentuale di pixel bianchi oltre la quale l'immagine viene eliminata (predefinito 95%).
    """
    # Ottieni la lista di file nella cartella
    files = os.listdir(cartella)
    
    # Filtra solo i file immagine (png, jpg, jpeg)
    immagini = [f for f in files if f.endswith(('.png', '.jpg', '.jpeg'))]
    
    for immagine in immagini:
        percorso_immagine = os.path.join(cartella, immagine)
        
        # Carica l'immagine
        try:
            with Image.open(percorso_immagine) as img:
                # Converti l'immagine in scala di grigi
                img_gray = img.convert('L')
                
                # Converti l'immagine in array numpy
                img_array = np.array(img_gray)
                
                # Calcola la percentuale di pixel sopra la soglia
                pixel_bianchi = np.sum(img_array >= soglia)
                percentuale_pixel_bianchi = pixel_bianchi / img_array.size
                
                # Se la percentuale di pixel bianchi è superiore alla soglia, elimina l'immagine
                if percentuale_pixel_bianchi >= percentuale_bianchi:
                    os.remove(percorso_immagine)
                    print(f"Rimosso: {immagine} (Percentuale pixel bianchi: {percentuale_pixel_bianchi:.2f})")
        
        except Exception as e:
            print(f"Errore nell'elaborazione dell'immagine {immagine}: {e}")

# Esempio di utilizzo
cartella = '/Users/roberto/Desktop/UNI 3^ ANNO/tesi/spettrogrammiTSLA,KK/spettrogrammi_KK'
rimuovi_immagini_bianche(cartella)
# Out:
# Rimosso: spettrogramma_anno_2020_trasformato_86.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_79.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_31.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_80.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_116.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_17.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_115.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_81.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_95.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_100.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_99.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_32.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_171.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_116.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_115.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_28.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_4.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_106.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_14.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_100.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_96.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_171.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_69.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_37.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_55.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_134.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_164.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_170.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_65.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_111.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_94.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_15.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_107.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_79.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_33.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_59.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_104.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_103.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_116.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_8.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_6.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_93.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_50.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_56.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_149.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_40.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_68.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_46.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_107.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_91.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_126.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_139.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_104.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_105.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_69.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_35.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_176.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_10.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_64.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_42.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_149.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_110.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_156.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_154.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_155.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_173.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_198.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_80.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_111.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_21.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_177.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_188.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_104.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_138.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_86.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_51.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_79.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_106.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_92.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_142.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_51.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_69.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_82.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_194.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_171.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_44.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_174.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_78.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_18.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_107.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_189.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_166.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_184.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_44.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_144.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_185.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_191.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_165.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_175.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_117.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_172.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_33.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_27.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_88.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_191.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_82.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_55.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_167.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_29.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_49.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_80.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_150.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_53.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_39.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_147.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_84.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_186.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_145.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_177.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_59.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_128.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_172.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_74.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_95.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_28.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_19.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_155.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_67.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_194.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_45.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_92.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_73.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_67.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_55.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_82.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_174.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_157.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_54.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_152.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_97.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_189.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_12.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_161.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_156.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_58.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_163.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_194.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_189.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_42.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_56.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_183.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_192.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_195.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_49.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_132.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_61.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_147.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_153.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_199.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_159.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_84.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_187.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_47.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_169.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_150.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_140.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_46.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_166.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_192.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_136.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_64.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_14.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_5.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_198.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_123.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_6.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_22.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_187.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_185.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_159.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_83.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_38.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_10.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_18.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_5.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_152.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_170.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_88.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_77.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_192.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_1.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_153.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_26.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_117.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_152.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_114.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_23.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_134.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_125.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_7.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_9.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_153.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_57.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_29.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_102.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_90.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_185.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_75.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_49.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_179.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_133.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_101.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_68.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_178.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_144.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_40.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_150.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_72.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2017_trasformato_30.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_145.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_87.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_192.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_124.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_16.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_89.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_139.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_132.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_12.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_197.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_140.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_133.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_111.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_25.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2022_trasformato_107.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_71.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2021_trasformato_86.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_29.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_4.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_142.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_133.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_27.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_157.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_5.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_130.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_135.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2014_trasformato_118.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_134.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2019_trasformato_142.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2013_trasformato_72.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2016_trasformato_10.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2020_trasformato_107.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2015_trasformato_28.png (Percentuale pixel bianchi: 0.96)
# Rimosso: spettrogramma_anno_2018_trasformato_194.png (Percentuale pixel bianchi: 0.96)
