# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import pywt
import pandas as pd
import os
from datetime import datetime, timedelta

# Step 1: Create Directory to Save Images and Labels
output_dir = "spectrograms_train"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

label_file = os.path.join(output_dir, "labels.csv")

# Step 2: Download Stock Data with Extended Periods
def download_data_with_extension(ticker, start_date, end_date, chunk_size_days, extension_days):
    """
    Download time series data for a given ticker, including an extension for future trend analysis.
    """
    current_date = start_date
    all_data = []

    while current_date < end_date:
        next_date = current_date + timedelta(days=chunk_size_days + extension_days)
        print(f"Downloading {ticker} data from {current_date} to {next_date}...")
        
        data = yf.download(ticker, start=current_date, end=next_date, progress=False)
        if not data.empty:
            all_data.append(data['Close'])
        
        current_date = current_date + timedelta(days=chunk_size_days)

    return pd.concat(all_data, axis=0)

# Step 3: Compute Future Trend Label
def compute_future_trend_label(future_period_prices, threshold=0.005):
    """
    Compute label based on the average price variation between current and future periods:
        1 -> Positive trend (average price increase > threshold)
        0 -> Neutral trend (within ±threshold)
       -1 -> Negative trend (average price decrease > threshold)
    """
    if len(future_period_prices) == 0:
        return None
    
    price_change = (future_period_prices[-1]-future_period_prices[0])/future_period_prices[0]

    if price_change > threshold:
        return 1  # Upwards trend
    elif price_change < -threshold:
        return -1  # Downwards trend
    else:
        return 0  # Neutral trend

# Step 4: Generate Wavelet Spectrogram and Save Image
def generate_wavelet_spectrogram(signal, stock_name, period_num, wavelet='morl', scales=None):
    """
    Generate and save a spectrogram image using Continuous Wavelet Transform (CWT).
    """
    if scales is None:
        scales = np.arange(1, 128)

    # Perform Continuous Wavelet Transform
    coefficients, frequencies = pywt.cwt(signal, scales, wavelet)
    
    # Plot the spectrogram
    plt.figure(figsize=(10, 6))
    plt.imshow(np.abs(coefficients), extent=[0, len(signal), 1, 128],
               interpolation='bilinear', aspect='auto', cmap='jet')
    plt.colorbar(label='Power')
    plt.ylabel('Frequency (Scale)')
    plt.xlabel('Time')
    plt.title(f'{stock_name} - Period {period_num} Spectrogram')

    # Save the image
    image_path = os.path.join(output_dir, f"{stock_name}_Period{period_num}.png")
    plt.savefig(image_path)
    plt.close()
    print(f"Saved spectrogram: {image_path}")

    return image_path


# Step 5: Process Stocks and Save Labels
def process_stocks(tickers, start_date, end_date, chunk_size_days=100, extension_days=30, threshold=0.005):
    """
    Download stock data, generate spectrograms, and assign labels based on future trends.
    """
    labels = []

    for ticker in tickers:
        print(f"Processing {ticker}...")
        try:
            # Download data with extension for future trend analysis
            close_prices = download_data_with_extension(ticker, start_date, end_date, chunk_size_days, extension_days)
            close_prices = close_prices.dropna()
            
            if len(close_prices) == 0:
                print(f"No valid data for {ticker}. Skipping...")
                continue
            
            # Process each 100-day period
            period_num = 1
            for i in range(0, len(close_prices) - chunk_size_days - extension_days + 1, chunk_size_days):
                current_chunk = close_prices.iloc[i:i + chunk_size_days].values
                future_chunk = close_prices.iloc[i + chunk_size_days:i + chunk_size_days + extension_days].values
                
                if len(current_chunk) < 2 or len(future_chunk) < 2:
                    continue
                
                # Compute label based on future trend
                label = compute_future_trend_label( future_chunk, threshold)
                if label is None:
                    continue
                
                # Generate and save spectrogram
                image_path = generate_wavelet_spectrogram(current_chunk, ticker, period_num)
                
                # Append to labels list
                labels.append([image_path, label])
                period_num += 1
                
        except Exception as e:
            print(f"Error processing {ticker}: {e}")

    # Save labels to CSV
    labels_df = pd.DataFrame(labels, columns=["image_path", "label"])
    labels_df.to_csv(label_file, index=False)
    print(f"Labels saved to {label_file}")


# Step 6: Main Execution
if __name__ == "__main__":
    # List of Stocks (First 10 for demonstration)
    tickers = [ "AAPL", "MSFT", "AMZN", "GOOG", "BRK-B", "NVDA", "JNJ", "JPM", "PG", "UNH", "HD", "MA", "DIS", "NFLX", "KO", "PEP",
    "CSCO", "XOM", "PFE", "MRK", "INTC", "BA", "WMT", "MCD", "IBM", "GS",
    "NKE", "ADBE", "HON", "AMGN", "T", "COST", "ABT", "LMT", "BMY", "CAT",
    "DHR", "MDT", "CVX", "ORCL", "CMCSA", "MS", "ISRG", "TXN", "UNP", "QCOM",
    "LIN", "PM", "SBUX", "AMAT", "MMM", "NEE", "BLK", "SPGI", "NOW", "GE",
    "LLY", "ZTS", "LOW", "TGT", "INTU", "ANTM", "MU", "FIS", "CSX", "VRTX",
    "GILD", "APD", "PLD", "ADI", "C", "DUK", "SYK", "USB", "SO", "SCHW",
    "MMC", "CL", "TJX", "BDX", "CI", "PNC", "CME", "NSC", "EW", "ETN",
    "ADI", "ROP", "FCX", "ICE", "TRV", "TMO", "GM", "AON", "FDX", "HUM"]
    
    # Define Date Range (2007 to 2017)
    start_date = datetime(2000, 1, 1)
    end_date = datetime(2014, 1, 1)
    
    # Process Stocks and Generate Spectrograms with Labels
    process_stocks(tickers, start_date, end_date)
# Out:
# Processing AAPL...
# Downloading AAPL data from 2000-01-01 00:00:00 to 2000-05-10 00:00:00...
# Downloading AAPL data from 2000-04-10 00:00:00 to 2000-08-18 00:00:00...
# Downloading AAPL data from 2000-07-19 00:00:00 to 2000-11-26 00:00:00...
# Downloading AAPL data from 2000-10-27 00:00:00 to 2001-03-06 00:00:00...
# Downloading AAPL data from 2001-02-04 00:00:00 to 2001-06-14 00:00:00...
# Downloading AAPL data from 2001-05-15 00:00:00 to 2001-09-22 00:00:00...
# Downloading AAPL data from 2001-08-23 00:00:00 to 2001-12-31 00:00:00...
# Downloading AAPL data from 2001-12-01 00:00:00 to 2002-04-10 00:00:00...
# Downloading AAPL data from 2002-03-11 00:00:00 to 2002-07-19 00:00:00...
# Downloading AAPL data from 2002-06-19 00:00:00 to 2002-10-27 00:00:00...
# Downloading AAPL data from 2002-09-27 00:00:00 to 2003-02-04 00:00:00...
# Downloading AAPL data from 2003-01-05 00:00:00 to 2003-05-15 00:00:00...
# Downloading AAPL data from 2003-04-15 00:00:00 to 2003-08-23 00:00:00...
# Downloading AAPL data from 2003-07-24 00:00:00 to 2003-12-01 00:00:00...
# Downloading AAPL data from 2003-11-01 00:00:00 to 2004-03-10 00:00:00...
# Downloading AAPL data from 2004-02-09 00:00:00 to 2004-06-18 00:00:00...
# Downloading AAPL data from 2004-05-19 00:00:00 to 2004-09-26 00:00:00...
# Downloading AAPL data from 2004-08-27 00:00:00 to 2005-01-04 00:00:00...
# Downloading AAPL data from 2004-12-05 00:00:00 to 2005-04-14 00:00:00...
# Downloading AAPL data from 2005-03-15 00:00:00 to 2005-07-23 00:00:00...
# Downloading AAPL data from 2005-06-23 00:00:00 to 2005-10-31 00:00:00...
# Downloading AAPL data from 2005-10-01 00:00:00 to 2006-02-08 00:00:00...
# Downloading AAPL data from 2006-01-09 00:00:00 to 2006-05-19 00:00:00...
# Downloading AAPL data from 2006-04-19 00:00:00 to 2006-08-27 00:00:00...
# Downloading AAPL data from 2006-07-28 00:00:00 to 2006-12-05 00:00:00...
# Downloading AAPL data from 2006-11-05 00:00:00 to 2007-03-15 00:00:00...
# Downloading AAPL data from 2007-02-13 00:00:00 to 2007-06-23 00:00:00...
# Downloading AAPL data from 2007-05-24 00:00:00 to 2007-10-01 00:00:00...
# Downloading AAPL data from 2007-09-01 00:00:00 to 2008-01-09 00:00:00...
# Downloading AAPL data from 2007-12-10 00:00:00 to 2008-04-18 00:00:00...
# Downloading AAPL data from 2008-03-19 00:00:00 to 2008-07-27 00:00:00...
# Downloading AAPL data from 2008-06-27 00:00:00 to 2008-11-04 00:00:00...
# Downloading AAPL data from 2008-10-05 00:00:00 to 2009-02-12 00:00:00...
# Downloading AAPL data from 2009-01-13 00:00:00 to 2009-05-23 00:00:00...
# Downloading AAPL data from 2009-04-23 00:00:00 to 2009-08-31 00:00:00...
# Downloading AAPL data from 2009-08-01 00:00:00 to 2009-12-09 00:00:00...
# Downloading AAPL data from 2009-11-09 00:00:00 to 2010-03-19 00:00:00...
# Downloading AAPL data from 2010-02-17 00:00:00 to 2010-06-27 00:00:00...
# Downloading AAPL data from 2010-05-28 00:00:00 to 2010-10-05 00:00:00...
# Downloading AAPL data from 2010-09-05 00:00:00 to 2011-01-13 00:00:00...
# Downloading AAPL data from 2010-12-14 00:00:00 to 2011-04-23 00:00:00...
# Downloading AAPL data from 2011-03-24 00:00:00 to 2011-08-01 00:00:00...
# Downloading AAPL data from 2011-07-02 00:00:00 to 2011-11-09 00:00:00...
# Downloading AAPL data from 2011-10-10 00:00:00 to 2012-02-17 00:00:00...
# Downloading AAPL data from 2012-01-18 00:00:00 to 2012-05-27 00:00:00...
# Downloading AAPL data from 2012-04-27 00:00:00 to 2012-09-04 00:00:00...
# Downloading AAPL data from 2012-08-05 00:00:00 to 2012-12-13 00:00:00...
# Downloading AAPL data from 2012-11-13 00:00:00 to 2013-03-23 00:00:00...
# Downloading AAPL data from 2013-02-21 00:00:00 to 2013-07-01 00:00:00...
# Downloading AAPL data from 2013-06-01 00:00:00 to 2013-10-09 00:00:00...
# Downloading AAPL data from 2013-09-09 00:00:00 to 2014-01-17 00:00:00...
# Downloading AAPL data from 2013-12-18 00:00:00 to 2014-04-27 00:00:00...
# Saved spectrogram: spectrograms_train/AAPL_Period1.png
# Saved spectrogram: spectrograms_train/AAPL_Period2.png
# Saved spectrogram: spectrograms_train/AAPL_Period3.png
# Saved spectrogram: spectrograms_train/AAPL_Period4.png
# Saved spectrogram: spectrograms_train/AAPL_Period5.png
# Saved spectrogram: spectrograms_train/AAPL_Period6.png
# Saved spectrogram: spectrograms_train/AAPL_Period7.png
# Saved spectrogram: spectrograms_train/AAPL_Period8.png
# Saved spectrogram: spectrograms_train/AAPL_Period9.png
# Saved spectrogram: spectrograms_train/AAPL_Period10.png
# Saved spectrogram: spectrograms_train/AAPL_Period11.png
# Saved spectrogram: spectrograms_train/AAPL_Period12.png
# Saved spectrogram: spectrograms_train/AAPL_Period13.png
# Saved spectrogram: spectrograms_train/AAPL_Period14.png
# Saved spectrogram: spectrograms_train/AAPL_Period15.png
# Saved spectrogram: spectrograms_train/AAPL_Period16.png
# Saved spectrogram: spectrograms_train/AAPL_Period17.png
# Saved spectrogram: spectrograms_train/AAPL_Period18.png
# Saved spectrogram: spectrograms_train/AAPL_Period19.png
# Saved spectrogram: spectrograms_train/AAPL_Period20.png
# Saved spectrogram: spectrograms_train/AAPL_Period21.png
# Saved spectrogram: spectrograms_train/AAPL_Period22.png
# Saved spectrogram: spectrograms_train/AAPL_Period23.png
# Saved spectrogram: spectrograms_train/AAPL_Period24.png
# Saved spectrogram: spectrograms_train/AAPL_Period25.png
# Saved spectrogram: spectrograms_train/AAPL_Period26.png
# Saved spectrogram: spectrograms_train/AAPL_Period27.png
# Saved spectrogram: spectrograms_train/AAPL_Period28.png
# Saved spectrogram: spectrograms_train/AAPL_Period29.png
# Saved spectrogram: spectrograms_train/AAPL_Period30.png
# Saved spectrogram: spectrograms_train/AAPL_Period31.png
# Saved spectrogram: spectrograms_train/AAPL_Period32.png
# Saved spectrogram: spectrograms_train/AAPL_Period33.png
# Saved spectrogram: spectrograms_train/AAPL_Period34.png
# Saved spectrogram: spectrograms_train/AAPL_Period35.png
# Saved spectrogram: spectrograms_train/AAPL_Period36.png
# Saved spectrogram: spectrograms_train/AAPL_Period37.png
# Saved spectrogram: spectrograms_train/AAPL_Period38.png
# Saved spectrogram: spectrograms_train/AAPL_Period39.png
# Saved spectrogram: spectrograms_train/AAPL_Period40.png
# Saved spectrogram: spectrograms_train/AAPL_Period41.png
# Saved spectrogram: spectrograms_train/AAPL_Period42.png
# Saved spectrogram: spectrograms_train/AAPL_Period43.png
# Saved spectrogram: spectrograms_train/AAPL_Period44.png
# Saved spectrogram: spectrograms_train/AAPL_Period45.png
# Saved spectrogram: spectrograms_train/AAPL_Period46.png
# Processing MSFT...
# Downloading MSFT data from 2000-01-01 00:00:00 to 2000-05-10 00:00:00...
# Downloading MSFT data from 2000-04-10 00:00:00 to 2000-08-18 00:00:00...
# Downloading MSFT data from 2000-07-19 00:00:00 to 2000-11-26 00:00:00...
# Downloading MSFT data from 2000-10-27 00:00:00 to 2001-03-06 00:00:00...
# Downloading MSFT data from 2001-02-04 00:00:00 to 2001-06-14 00:00:00...
# Downloading MSFT data from 2001-05-15 00:00:00 to 2001-09-22 00:00:00...
# Downloading MSFT data from 2001-08-23 00:00:00 to 2001-12-31 00:00:00...
# Downloading MSFT data from 2001-12-01 00:00:00 to 2002-04-10 00:00:00...
# Downloading MSFT data from 2002-03-11 00:00:00 to 2002-07-19 00:00:00...
# Downloading MSFT data from 2002-06-19 00:00:00 to 2002-10-27 00:00:00...
# Downloading MSFT data from 2002-09-27 00:00:00 to 2003-02-04 00:00:00...
# Downloading MSFT data from 2003-01-05 00:00:00 to 2003-05-15 00:00:00...
# Downloading MSFT data from 2003-04-15 00:00:00 to 2003-08-23 00:00:00...
# Downloading MSFT data from 2003-07-24 00:00:00 to 2003-12-01 00:00:00...
# Downloading MSFT data from 2003-11-01 00:00:00 to 2004-03-10 00:00:00...
# Downloading MSFT data from 2004-02-09 00:00:00 to 2004-06-18 00:00:00...
# Downloading MSFT data from 2004-05-19 00:00:00 to 2004-09-26 00:00:00...
# Downloading MSFT data from 2004-08-27 00:00:00 to 2005-01-04 00:00:00...
# Downloading MSFT data from 2004-12-05 00:00:00 to 2005-04-14 00:00:00...
# Downloading MSFT data from 2005-03-15 00:00:00 to 2005-07-23 00:00:00...
# Downloading MSFT data from 2005-06-23 00:00:00 to 2005-10-31 00:00:00...
# Downloading MSFT data from 2005-10-01 00:00:00 to 2006-02-08 00:00:00...
# Downloading MSFT data from 2006-01-09 00:00:00 to 2006-05-19 00:00:00...
# Downloading MSFT data from 2006-04-19 00:00:00 to 2006-08-27 00:00:00...
# Downloading MSFT data from 2006-07-28 00:00:00 to 2006-12-05 00:00:00...
# Downloading MSFT data from 2006-11-05 00:00:00 to 2007-03-15 00:00:00...
# Downloading MSFT data from 2007-02-13 00:00:00 to 2007-06-23 00:00:00...
# Downloading MSFT data from 2007-05-24 00:00:00 to 2007-10-01 00:00:00...
# Downloading MSFT data from 2007-09-01 00:00:00 to 2008-01-09 00:00:00...
# Downloading MSFT data from 2007-12-10 00:00:00 to 2008-04-18 00:00:00...
# Downloading MSFT data from 2008-03-19 00:00:00 to 2008-07-27 00:00:00...
# Downloading MSFT data from 2008-06-27 00:00:00 to 2008-11-04 00:00:00...
# Downloading MSFT data from 2008-10-05 00:00:00 to 2009-02-12 00:00:00...
# Downloading MSFT data from 2009-01-13 00:00:00 to 2009-05-23 00:00:00...
# Downloading MSFT data from 2009-04-23 00:00:00 to 2009-08-31 00:00:00...
# Downloading MSFT data from 2009-08-01 00:00:00 to 2009-12-09 00:00:00...
# Downloading MSFT data from 2009-11-09 00:00:00 to 2010-03-19 00:00:00...
# Downloading MSFT data from 2010-02-17 00:00:00 to 2010-06-27 00:00:00...
# Downloading MSFT data from 2010-05-28 00:00:00 to 2010-10-05 00:00:00...
# Downloading MSFT data from 2010-09-05 00:00:00 to 2011-01-13 00:00:00...
# Downloading MSFT data from 2010-12-14 00:00:00 to 2011-04-23 00:00:00...
# Downloading MSFT data from 2011-03-24 00:00:00 to 2011-08-01 00:00:00...
# Downloading MSFT data from 2011-07-02 00:00:00 to 2011-11-09 00:00:00...
# Downloading MSFT data from 2011-10-10 00:00:00 to 2012-02-17 00:00:00...
# Downloading MSFT data from 2012-01-18 00:00:00 to 2012-05-27 00:00:00...
# Downloading MSFT data from 2012-04-27 00:00:00 to 2012-09-04 00:00:00...
# Downloading MSFT data from 2012-08-05 00:00:00 to 2012-12-13 00:00:00...
# Downloading MSFT data from 2012-11-13 00:00:00 to 2013-03-23 00:00:00...
# Downloading MSFT data from 2013-02-21 00:00:00 to 2013-07-01 00:00:00...
# Downloading MSFT data from 2013-06-01 00:00:00 to 2013-10-09 00:00:00...
# Downloading MSFT data from 2013-09-09 00:00:00 to 2014-01-17 00:00:00...
# Downloading MSFT data from 2013-12-18 00:00:00 to 2014-04-27 00:00:00...
# Saved spectrogram: spectrograms_train/MSFT_Period1.png
# Saved spectrogram: spectrograms_train/MSFT_Period2.png
# Saved spectrogram: spectrograms_train/MSFT_Period3.png
# Saved spectrogram: spectrograms_train/MSFT_Period4.png
# Saved spectrogram: spectrograms_train/MSFT_Period5.png
# Saved spectrogram: spectrograms_train/MSFT_Period6.png
# Saved spectrogram: spectrograms_train/MSFT_Period7.png
# Saved spectrogram: spectrograms_train/MSFT_Period8.png
# Saved spectrogram: spectrograms_train/MSFT_Period9.png
# Saved spectrogram: spectrograms_train/MSFT_Period10.png
# Saved spectrogram: spectrograms_train/MSFT_Period11.png
# Saved spectrogram: spectrograms_train/MSFT_Period12.png
# Saved spectrogram: spectrograms_train/MSFT_Period13.png
# Saved spectrogram: spectrograms_train/MSFT_Period14.png
# Saved spectrogram: spectrograms_train/MSFT_Period15.png
# Saved spectrogram: spectrograms_train/MSFT_Period16.png
# Saved spectrogram: spectrograms_train/MSFT_Period17.png
# Saved spectrogram: spectrograms_train/MSFT_Period18.png
# Saved spectrogram: spectrograms_train/MSFT_Period19.png
# Saved spectrogram: spectrograms_train/MSFT_Period20.png
# Saved spectrogram: spectrograms_train/MSFT_Period21.png
# Saved spectrogram: spectrograms_train/MSFT_Period22.png
# Saved spectrogram: spectrograms_train/MSFT_Period23.png
# Saved spectrogram: spectrograms_train/MSFT_Period24.png
# Saved spectrogram: spectrograms_train/MSFT_Period25.png
# Saved spectrogram: spectrograms_train/MSFT_Period26.png
# Saved spectrogram: spectrograms_train/MSFT_Period27.png
# Saved spectrogram: spectrograms_train/MSFT_Period28.png
# Saved spectrogram: spectrograms_train/MSFT_Period29.png
# Saved spectrogram: spectrograms_train/MSFT_Period30.png
# Saved spectrogram: spectrograms_train/MSFT_Period31.png
# Saved spectrogram: spectrograms_train/MSFT_Period32.png
# Saved spectrogram: spectrograms_train/MSFT_Period33.png
# Saved spectrogram: spectrograms_train/MSFT_Period34.png
# Saved spectrogram: spectrograms_train/MSFT_Period35.png
# Saved spectrogram: spectrograms_train/MSFT_Period36.png
# Saved spectrogram: spectrograms_train/MSFT_Period37.png
# Saved spectrogram: spectrograms_train/MSFT_Period38.png
# Saved spectrogram: spectrograms_train/MSFT_Period39.png
# Saved spectrogram: spectrograms_train/MSFT_Period40.png
# Saved spectrogram: spectrograms_train/MSFT_Period41.png
# Saved spectrogram: spectrograms_train/MSFT_Period42.png
# Saved spectrogram: spectrograms_train/MSFT_Period43.png
# Saved spectrogram: spectrograms_train/MSFT_Period44.png
# Saved spectrogram: spectrograms_train/MSFT_Period45.png
# Saved spectrogram: spectrograms_train/MSFT_Period46.png
# Processing AMZN...
# Downloading AMZN data from 2000-01-01 00:00:00 to 2000-05-10 00:00:00...
# Downloading AMZN data from 2000-04-10 00:00:00 to 2000-08-18 00:00:00...
# Downloading AMZN data from 2000-07-19 00:00:00 to 2000-11-26 00:00:00...
# Downloading AMZN data from 2000-10-27 00:00:00 to 2001-03-06 00:00:00...
# Downloading AMZN data from 2001-02-04 00:00:00 to 2001-06-14 00:00:00...
# Downloading AMZN data from 2001-05-15 00:00:00 to 2001-09-22 00:00:00...
# Downloading AMZN data from 2001-08-23 00:00:00 to 2001-12-31 00:00:00...
# Downloading AMZN data from 2001-12-01 00:00:00 to 2002-04-10 00:00:00...
# Downloading AMZN data from 2002-03-11 00:00:00 to 2002-07-19 00:00:00...
# Downloading AMZN data from 2002-06-19 00:00:00 to 2002-10-27 00:00:00...
# Downloading AMZN data from 2002-09-27 00:00:00 to 2003-02-04 00:00:00...
# Downloading AMZN data from 2003-01-05 00:00:00 to 2003-05-15 00:00:00...
# Downloading AMZN data from 2003-04-15 00:00:00 to 2003-08-23 00:00:00...
# Downloading AMZN data from 2003-07-24 00:00:00 to 2003-12-01 00:00:00...
# Downloading AMZN data from 2003-11-01 00:00:00 to 2004-03-10 00:00:00...
# Downloading AMZN data from 2004-02-09 00:00:00 to 2004-06-18 00:00:00...
# Downloading AMZN data from 2004-05-19 00:00:00 to 2004-09-26 00:00:00...
# Downloading AMZN data from 2004-08-27 00:00:00 to 2005-01-04 00:00:00...
# Downloading AMZN data from 2004-12-05 00:00:00 to 2005-04-14 00:00:00...
# Downloading AMZN data from 2005-03-15 00:00:00 to 2005-07-23 00:00:00...
# Downloading AMZN data from 2005-06-23 00:00:00 to 2005-10-31 00:00:00...
# Downloading AMZN data from 2005-10-01 00:00:00 to 2006-02-08 00:00:00...
# Downloading AMZN data from 2006-01-09 00:00:00 to 2006-05-19 00:00:00...
# Downloading AMZN data from 2006-04-19 00:00:00 to 2006-08-27 00:00:00...
# Downloading AMZN data from 2006-07-28 00:00:00 to 2006-12-05 00:00:00...
# Downloading AMZN data from 2006-11-05 00:00:00 to 2007-03-15 00:00:00...
# Downloading AMZN data from 2007-02-13 00:00:00 to 2007-06-23 00:00:00...
# Downloading AMZN data from 2007-05-24 00:00:00 to 2007-10-01 00:00:00...
# Downloading AMZN data from 2007-09-01 00:00:00 to 2008-01-09 00:00:00...
# Downloading AMZN data from 2007-12-10 00:00:00 to 2008-04-18 00:00:00...
# Downloading AMZN data from 2008-03-19 00:00:00 to 2008-07-27 00:00:00...
# Downloading AMZN data from 2008-06-27 00:00:00 to 2008-11-04 00:00:00...
# Downloading AMZN data from 2008-10-05 00:00:00 to 2009-02-12 00:00:00...
# Downloading AMZN data from 2009-01-13 00:00:00 to 2009-05-23 00:00:00...
# Downloading AMZN data from 2009-04-23 00:00:00 to 2009-08-31 00:00:00...
# Downloading AMZN data from 2009-08-01 00:00:00 to 2009-12-09 00:00:00...
# Downloading AMZN data from 2009-11-09 00:00:00 to 2010-03-19 00:00:00...
# Downloading AMZN data from 2010-02-17 00:00:00 to 2010-06-27 00:00:00...
# Downloading AMZN data from 2010-05-28 00:00:00 to 2010-10-05 00:00:00...
# Downloading AMZN data from 2010-09-05 00:00:00 to 2011-01-13 00:00:00...
# Downloading AMZN data from 2010-12-14 00:00:00 to 2011-04-23 00:00:00...
# Downloading AMZN data from 2011-03-24 00:00:00 to 2011-08-01 00:00:00...
# Downloading AMZN data from 2011-07-02 00:00:00 to 2011-11-09 00:00:00...
# Downloading AMZN data from 2011-10-10 00:00:00 to 2012-02-17 00:00:00...
# Downloading AMZN data from 2012-01-18 00:00:00 to 2012-05-27 00:00:00...
# Downloading AMZN data from 2012-04-27 00:00:00 to 2012-09-04 00:00:00...
# Downloading AMZN data from 2012-08-05 00:00:00 to 2012-12-13 00:00:00...
# Downloading AMZN data from 2012-11-13 00:00:00 to 2013-03-23 00:00:00...
# Downloading AMZN data from 2013-02-21 00:00:00 to 2013-07-01 00:00:00...
# Downloading AMZN data from 2013-06-01 00:00:00 to 2013-10-09 00:00:00...
# Downloading AMZN data from 2013-09-09 00:00:00 to 2014-01-17 00:00:00...
# Downloading AMZN data from 2013-12-18 00:00:00 to 2014-04-27 00:00:00...
# Saved spectrogram: spectrograms_train/AMZN_Period1.png
# Saved spectrogram: spectrograms_train/AMZN_Period2.png
# Saved spectrogram: spectrograms_train/AMZN_Period3.png
# Saved spectrogram: spectrograms_train/AMZN_Period4.png
# Saved spectrogram: spectrograms_train/AMZN_Period5.png
# Saved spectrogram: spectrograms_train/AMZN_Period6.png
# Saved spectrogram: spectrograms_train/AMZN_Period7.png
# Saved spectrogram: spectrograms_train/AMZN_Period8.png
# Saved spectrogram: spectrograms_train/AMZN_Period9.png
# Saved spectrogram: spectrograms_train/AMZN_Period10.png
# Saved spectrogram: spectrograms_train/AMZN_Period11.png
# Saved spectrogram: spectrograms_train/AMZN_Period12.png
# Saved spectrogram: spectrograms_train/AMZN_Period13.png
# Saved spectrogram: spectrograms_train/AMZN_Period14.png
# Saved spectrogram: spectrograms_train/AMZN_Period15.png
# Saved spectrogram: spectrograms_train/AMZN_Period16.png
# Saved spectrogram: spectrograms_train/AMZN_Period17.png
# Saved spectrogram: spectrograms_train/AMZN_Period18.png
# Saved spectrogram: spectrograms_train/AMZN_Period19.png
# Saved spectrogram: spectrograms_train/AMZN_Period20.png
# Saved spectrogram: spectrograms_train/AMZN_Period21.png
# Saved spectrogram: spectrograms_train/AMZN_Period22.png
# Saved spectrogram: spectrograms_train/AMZN_Period23.png
# Saved spectrogram: spectrograms_train/AMZN_Period24.png
# Saved spectrogram: spectrograms_train/AMZN_Period25.png
# Saved spectrogram: spectrograms_train/AMZN_Period26.png
# Saved spectrogram: spectrograms_train/AMZN_Period27.png
# Saved spectrogram: spectrograms_train/AMZN_Period28.png
# Saved spectrogram: spectrograms_train/AMZN_Period29.png
# Saved spectrogram: spectrograms_train/AMZN_Period30.png
# Saved spectrogram: spectrograms_train/AMZN_Period31.png
# Saved spectrogram: spectrograms_train/AMZN_Period32.png
# Saved spectrogram: spectrograms_train/AMZN_Period33.png
# Saved spectrogram: spectrograms_train/AMZN_Period34.png
# Saved spectrogram: spectrograms_train/AMZN_Period35.png
# Saved spectrogram: spectrograms_train/AMZN_Period36.png
# Saved spectrogram: spectrograms_train/AMZN_Period37.png
# Saved spectrogram: spectrograms_train/AMZN_Period38.png
# Saved spectrogram: spectrograms_train/AMZN_Period39.png
# Saved spectrogram: spectrograms_train/AMZN_Period40.png
# Saved spectrogram: spectrograms_train/AMZN_Period41.png
# Saved spectrogram: spectrograms_train/AMZN_Period42.png
# Saved spectrogram: spectrograms_train/AMZN_Period43.png
# Saved spectrogram: spectrograms_train/AMZN_Period44.png
# Saved spectrogram: spectrograms_train/AMZN_Period45.png
# Saved spectrogram: spectrograms_train/AMZN_Period46.png
# Processing GOOG...
# Downloading GOOG data from 2000-01-01 00:00:00 to 2000-05-10 00:00:00...
# 1 Failed download:
# ['GOOG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2000-01-01 00:00:00 -> 2000-05-10 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 946702800, endDate = 957931200")')
# Downloading GOOG data from 2000-04-10 00:00:00 to 2000-08-18 00:00:00...
# 1 Failed download:
# ['GOOG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2000-04-10 00:00:00 -> 2000-08-18 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 955339200, endDate = 966571200")')
# Downloading GOOG data from 2000-07-19 00:00:00 to 2000-11-26 00:00:00...
# 1 Failed download:
# ['GOOG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2000-07-19 00:00:00 -> 2000-11-26 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 963979200, endDate = 975214800")')
# Downloading GOOG data from 2000-10-27 00:00:00 to 2001-03-06 00:00:00...
# 1 Failed download:
# ['GOOG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2000-10-27 00:00:00 -> 2001-03-06 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 972619200, endDate = 983854800")')
# Downloading GOOG data from 2001-02-04 00:00:00 to 2001-06-14 00:00:00...
# 1 Failed download:
# ['GOOG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2001-02-04 00:00:00 -> 2001-06-14 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 981262800, endDate = 992491200")')
# Downloading GOOG data from 2001-05-15 00:00:00 to 2001-09-22 00:00:00...
# 1 Failed download:
# ['GOOG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2001-05-15 00:00:00 -> 2001-09-22 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 989899200, endDate = 1001131200")')
# Downloading GOOG data from 2001-08-23 00:00:00 to 2001-12-31 00:00:00...
# 1 Failed download:
# ['GOOG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2001-08-23 00:00:00 -> 2001-12-31 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 998539200, endDate = 1009774800")')
# Downloading GOOG data from 2001-12-01 00:00:00 to 2002-04-10 00:00:00...
# 1 Failed download:
# ['GOOG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2001-12-01 00:00:00 -> 2002-04-10 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1007182800, endDate = 1018411200")')
# Downloading GOOG data from 2002-03-11 00:00:00 to 2002-07-19 00:00:00...
# 1 Failed download:
# ['GOOG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2002-03-11 00:00:00 -> 2002-07-19 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1015822800, endDate = 1027051200")')
# Downloading GOOG data from 2002-06-19 00:00:00 to 2002-10-27 00:00:00...
# 1 Failed download:
# ['GOOG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2002-06-19 00:00:00 -> 2002-10-27 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1024459200, endDate = 1035691200")')
# Downloading GOOG data from 2002-09-27 00:00:00 to 2003-02-04 00:00:00...
# 1 Failed download:
# ['GOOG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2002-09-27 00:00:00 -> 2003-02-04 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1033099200, endDate = 1044334800")')
# Downloading GOOG data from 2003-01-05 00:00:00 to 2003-05-15 00:00:00...
# 1 Failed download:
# ['GOOG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2003-01-05 00:00:00 -> 2003-05-15 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1041742800, endDate = 1052971200")')
# Downloading GOOG data from 2003-04-15 00:00:00 to 2003-08-23 00:00:00...
# 1 Failed download:
# ['GOOG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2003-04-15 00:00:00 -> 2003-08-23 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1050379200, endDate = 1061611200")')
# Downloading GOOG data from 2003-07-24 00:00:00 to 2003-12-01 00:00:00...
# 1 Failed download:
# ['GOOG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2003-07-24 00:00:00 -> 2003-12-01 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1059019200, endDate = 1070254800")')
# Downloading GOOG data from 2003-11-01 00:00:00 to 2004-03-10 00:00:00...
# 1 Failed download:
# ['GOOG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2003-11-01 00:00:00 -> 2004-03-10 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1067662800, endDate = 1078894800")')
# Downloading GOOG data from 2004-02-09 00:00:00 to 2004-06-18 00:00:00...
# 1 Failed download:
# ['GOOG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2004-02-09 00:00:00 -> 2004-06-18 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1076302800, endDate = 1087531200")')
# Downloading GOOG data from 2004-05-19 00:00:00 to 2004-09-26 00:00:00...
# Downloading GOOG data from 2004-08-27 00:00:00 to 2005-01-04 00:00:00...
# Downloading GOOG data from 2004-12-05 00:00:00 to 2005-04-14 00:00:00...
# Downloading GOOG data from 2005-03-15 00:00:00 to 2005-07-23 00:00:00...
# Downloading GOOG data from 2005-06-23 00:00:00 to 2005-10-31 00:00:00...
# Downloading GOOG data from 2005-10-01 00:00:00 to 2006-02-08 00:00:00...
# Downloading GOOG data from 2006-01-09 00:00:00 to 2006-05-19 00:00:00...
# Downloading GOOG data from 2006-04-19 00:00:00 to 2006-08-27 00:00:00...
# Downloading GOOG data from 2006-07-28 00:00:00 to 2006-12-05 00:00:00...
# Downloading GOOG data from 2006-11-05 00:00:00 to 2007-03-15 00:00:00...
# Downloading GOOG data from 2007-02-13 00:00:00 to 2007-06-23 00:00:00...
# Downloading GOOG data from 2007-05-24 00:00:00 to 2007-10-01 00:00:00...
# Downloading GOOG data from 2007-09-01 00:00:00 to 2008-01-09 00:00:00...
# Downloading GOOG data from 2007-12-10 00:00:00 to 2008-04-18 00:00:00...
# Downloading GOOG data from 2008-03-19 00:00:00 to 2008-07-27 00:00:00...
# Downloading GOOG data from 2008-06-27 00:00:00 to 2008-11-04 00:00:00...
# Downloading GOOG data from 2008-10-05 00:00:00 to 2009-02-12 00:00:00...
# Downloading GOOG data from 2009-01-13 00:00:00 to 2009-05-23 00:00:00...
# Downloading GOOG data from 2009-04-23 00:00:00 to 2009-08-31 00:00:00...
# Downloading GOOG data from 2009-08-01 00:00:00 to 2009-12-09 00:00:00...
# Downloading GOOG data from 2009-11-09 00:00:00 to 2010-03-19 00:00:00...
# Downloading GOOG data from 2010-02-17 00:00:00 to 2010-06-27 00:00:00...
# Downloading GOOG data from 2010-05-28 00:00:00 to 2010-10-05 00:00:00...
# Downloading GOOG data from 2010-09-05 00:00:00 to 2011-01-13 00:00:00...
# Downloading GOOG data from 2010-12-14 00:00:00 to 2011-04-23 00:00:00...
# Downloading GOOG data from 2011-03-24 00:00:00 to 2011-08-01 00:00:00...
# Downloading GOOG data from 2011-07-02 00:00:00 to 2011-11-09 00:00:00...
# Downloading GOOG data from 2011-10-10 00:00:00 to 2012-02-17 00:00:00...
# Downloading GOOG data from 2012-01-18 00:00:00 to 2012-05-27 00:00:00...
# Downloading GOOG data from 2012-04-27 00:00:00 to 2012-09-04 00:00:00...
# Downloading GOOG data from 2012-08-05 00:00:00 to 2012-12-13 00:00:00...
# Downloading GOOG data from 2012-11-13 00:00:00 to 2013-03-23 00:00:00...
# Downloading GOOG data from 2013-02-21 00:00:00 to 2013-07-01 00:00:00...
# Downloading GOOG data from 2013-06-01 00:00:00 to 2013-10-09 00:00:00...
# Downloading GOOG data from 2013-09-09 00:00:00 to 2014-01-17 00:00:00...
# Downloading GOOG data from 2013-12-18 00:00:00 to 2014-04-27 00:00:00...
# Saved spectrogram: spectrograms_train/GOOG_Period1.png
# Saved spectrogram: spectrograms_train/GOOG_Period2.png
# Saved spectrogram: spectrograms_train/GOOG_Period3.png
# Saved spectrogram: spectrograms_train/GOOG_Period4.png
# Saved spectrogram: spectrograms_train/GOOG_Period5.png
# Saved spectrogram: spectrograms_train/GOOG_Period6.png
# Saved spectrogram: spectrograms_train/GOOG_Period7.png
# Saved spectrogram: spectrograms_train/GOOG_Period8.png
# Saved spectrogram: spectrograms_train/GOOG_Period9.png
# Saved spectrogram: spectrograms_train/GOOG_Period10.png
# Saved spectrogram: spectrograms_train/GOOG_Period11.png
# Saved spectrogram: spectrograms_train/GOOG_Period12.png
# Saved spectrogram: spectrograms_train/GOOG_Period13.png
# Saved spectrogram: spectrograms_train/GOOG_Period14.png
# Saved spectrogram: spectrograms_train/GOOG_Period15.png
# Saved spectrogram: spectrograms_train/GOOG_Period16.png
# Saved spectrogram: spectrograms_train/GOOG_Period17.png
# Saved spectrogram: spectrograms_train/GOOG_Period18.png
# Saved spectrogram: spectrograms_train/GOOG_Period19.png
# Saved spectrogram: spectrograms_train/GOOG_Period20.png
# Saved spectrogram: spectrograms_train/GOOG_Period21.png
# Saved spectrogram: spectrograms_train/GOOG_Period22.png
# Saved spectrogram: spectrograms_train/GOOG_Period23.png
# Saved spectrogram: spectrograms_train/GOOG_Period24.png
# Saved spectrogram: spectrograms_train/GOOG_Period25.png
# Saved spectrogram: spectrograms_train/GOOG_Period26.png
# Saved spectrogram: spectrograms_train/GOOG_Period27.png
# Saved spectrogram: spectrograms_train/GOOG_Period28.png
# Saved spectrogram: spectrograms_train/GOOG_Period29.png
# Saved spectrogram: spectrograms_train/GOOG_Period30.png
# Saved spectrogram: spectrograms_train/GOOG_Period31.png
# Processing BRK-B...
# Downloading BRK-B data from 2000-01-01 00:00:00 to 2000-05-10 00:00:00...
# Downloading BRK-B data from 2000-04-10 00:00:00 to 2000-08-18 00:00:00...
# Downloading BRK-B data from 2000-07-19 00:00:00 to 2000-11-26 00:00:00...
# Downloading BRK-B data from 2000-10-27 00:00:00 to 2001-03-06 00:00:00...
# Downloading BRK-B data from 2001-02-04 00:00:00 to 2001-06-14 00:00:00...
# Downloading BRK-B data from 2001-05-15 00:00:00 to 2001-09-22 00:00:00...
# Downloading BRK-B data from 2001-08-23 00:00:00 to 2001-12-31 00:00:00...
# Downloading BRK-B data from 2001-12-01 00:00:00 to 2002-04-10 00:00:00...
# Downloading BRK-B data from 2002-03-11 00:00:00 to 2002-07-19 00:00:00...
# Downloading BRK-B data from 2002-06-19 00:00:00 to 2002-10-27 00:00:00...
# Downloading BRK-B data from 2002-09-27 00:00:00 to 2003-02-04 00:00:00...
# Downloading BRK-B data from 2003-01-05 00:00:00 to 2003-05-15 00:00:00...
# Downloading BRK-B data from 2003-04-15 00:00:00 to 2003-08-23 00:00:00...
# Downloading BRK-B data from 2003-07-24 00:00:00 to 2003-12-01 00:00:00...
# Downloading BRK-B data from 2003-11-01 00:00:00 to 2004-03-10 00:00:00...
# Downloading BRK-B data from 2004-02-09 00:00:00 to 2004-06-18 00:00:00...
# Downloading BRK-B data from 2004-05-19 00:00:00 to 2004-09-26 00:00:00...
# Downloading BRK-B data from 2004-08-27 00:00:00 to 2005-01-04 00:00:00...
# Downloading BRK-B data from 2004-12-05 00:00:00 to 2005-04-14 00:00:00...
# Downloading BRK-B data from 2005-03-15 00:00:00 to 2005-07-23 00:00:00...
# Downloading BRK-B data from 2005-06-23 00:00:00 to 2005-10-31 00:00:00...
# Downloading BRK-B data from 2005-10-01 00:00:00 to 2006-02-08 00:00:00...
# Downloading BRK-B data from 2006-01-09 00:00:00 to 2006-05-19 00:00:00...
# Downloading BRK-B data from 2006-04-19 00:00:00 to 2006-08-27 00:00:00...
# Downloading BRK-B data from 2006-07-28 00:00:00 to 2006-12-05 00:00:00...
# Downloading BRK-B data from 2006-11-05 00:00:00 to 2007-03-15 00:00:00...
# Downloading BRK-B data from 2007-02-13 00:00:00 to 2007-06-23 00:00:00...
# Downloading BRK-B data from 2007-05-24 00:00:00 to 2007-10-01 00:00:00...
# Downloading BRK-B data from 2007-09-01 00:00:00 to 2008-01-09 00:00:00...
# Downloading BRK-B data from 2007-12-10 00:00:00 to 2008-04-18 00:00:00...
# Downloading BRK-B data from 2008-03-19 00:00:00 to 2008-07-27 00:00:00...
# Downloading BRK-B data from 2008-06-27 00:00:00 to 2008-11-04 00:00:00...
# Downloading BRK-B data from 2008-10-05 00:00:00 to 2009-02-12 00:00:00...
# Downloading BRK-B data from 2009-01-13 00:00:00 to 2009-05-23 00:00:00...
# Downloading BRK-B data from 2009-04-23 00:00:00 to 2009-08-31 00:00:00...
# Downloading BRK-B data from 2009-08-01 00:00:00 to 2009-12-09 00:00:00...
# Downloading BRK-B data from 2009-11-09 00:00:00 to 2010-03-19 00:00:00...
# Downloading BRK-B data from 2010-02-17 00:00:00 to 2010-06-27 00:00:00...
# Downloading BRK-B data from 2010-05-28 00:00:00 to 2010-10-05 00:00:00...
# Downloading BRK-B data from 2010-09-05 00:00:00 to 2011-01-13 00:00:00...
# Downloading BRK-B data from 2010-12-14 00:00:00 to 2011-04-23 00:00:00...
# Downloading BRK-B data from 2011-03-24 00:00:00 to 2011-08-01 00:00:00...
# Downloading BRK-B data from 2011-07-02 00:00:00 to 2011-11-09 00:00:00...
# Downloading BRK-B data from 2011-10-10 00:00:00 to 2012-02-17 00:00:00...
# Downloading BRK-B data from 2012-01-18 00:00:00 to 2012-05-27 00:00:00...
# Downloading BRK-B data from 2012-04-27 00:00:00 to 2012-09-04 00:00:00...
# Downloading BRK-B data from 2012-08-05 00:00:00 to 2012-12-13 00:00:00...
# Downloading BRK-B data from 2012-11-13 00:00:00 to 2013-03-23 00:00:00...
# Downloading BRK-B data from 2013-02-21 00:00:00 to 2013-07-01 00:00:00...
# Downloading BRK-B data from 2013-06-01 00:00:00 to 2013-10-09 00:00:00...
# Downloading BRK-B data from 2013-09-09 00:00:00 to 2014-01-17 00:00:00...
# Downloading BRK-B data from 2013-12-18 00:00:00 to 2014-04-27 00:00:00...
# Saved spectrogram: spectrograms_train/BRK-B_Period1.png
# Saved spectrogram: spectrograms_train/BRK-B_Period2.png
# Saved spectrogram: spectrograms_train/BRK-B_Period3.png
# Saved spectrogram: spectrograms_train/BRK-B_Period4.png
# Saved spectrogram: spectrograms_train/BRK-B_Period5.png
# Saved spectrogram: spectrograms_train/BRK-B_Period6.png
# Saved spectrogram: spectrograms_train/BRK-B_Period7.png
# Saved spectrogram: spectrograms_train/BRK-B_Period8.png
# Saved spectrogram: spectrograms_train/BRK-B_Period9.png
# Saved spectrogram: spectrograms_train/BRK-B_Period10.png
# Saved spectrogram: spectrograms_train/BRK-B_Period11.png
# Saved spectrogram: spectrograms_train/BRK-B_Period12.png
# Saved spectrogram: spectrograms_train/BRK-B_Period13.png
# Saved spectrogram: spectrograms_train/BRK-B_Period14.png
# Saved spectrogram: spectrograms_train/BRK-B_Period15.png
# Saved spectrogram: spectrograms_train/BRK-B_Period16.png
# Saved spectrogram: spectrograms_train/BRK-B_Period17.png
# Saved spectrogram: spectrograms_train/BRK-B_Period18.png
# Saved spectrogram: spectrograms_train/BRK-B_Period19.png
# Saved spectrogram: spectrograms_train/BRK-B_Period20.png
# Saved spectrogram: spectrograms_train/BRK-B_Period21.png
# Saved spectrogram: spectrograms_train/BRK-B_Period22.png
# Saved spectrogram: spectrograms_train/BRK-B_Period23.png
# Saved spectrogram: spectrograms_train/BRK-B_Period24.png
# Saved spectrogram: spectrograms_train/BRK-B_Period25.png
# Saved spectrogram: spectrograms_train/BRK-B_Period26.png
# Saved spectrogram: spectrograms_train/BRK-B_Period27.png
# Saved spectrogram: spectrograms_train/BRK-B_Period28.png
# Saved spectrogram: spectrograms_train/BRK-B_Period29.png
# Saved spectrogram: spectrograms_train/BRK-B_Period30.png
# Saved spectrogram: spectrograms_train/BRK-B_Period31.png
# Saved spectrogram: spectrograms_train/BRK-B_Period32.png
# Saved spectrogram: spectrograms_train/BRK-B_Period33.png
# Saved spectrogram: spectrograms_train/BRK-B_Period34.png
# Saved spectrogram: spectrograms_train/BRK-B_Period35.png
# Saved spectrogram: spectrograms_train/BRK-B_Period36.png
# Saved spectrogram: spectrograms_train/BRK-B_Period37.png
# Saved spectrogram: spectrograms_train/BRK-B_Period38.png
# Saved spectrogram: spectrograms_train/BRK-B_Period39.png
# Saved spectrogram: spectrograms_train/BRK-B_Period40.png
# Saved spectrogram: spectrograms_train/BRK-B_Period41.png
# Saved spectrogram: spectrograms_train/BRK-B_Period42.png
# Saved spectrogram: spectrograms_train/BRK-B_Period43.png
# Saved spectrogram: spectrograms_train/BRK-B_Period44.png
# Saved spectrogram: spectrograms_train/BRK-B_Period45.png
# Saved spectrogram: spectrograms_train/BRK-B_Period46.png
# Processing NVDA...
# Downloading NVDA data from 2000-01-01 00:00:00 to 2000-05-10 00:00:00...
# Downloading NVDA data from 2000-04-10 00:00:00 to 2000-08-18 00:00:00...
# Downloading NVDA data from 2000-07-19 00:00:00 to 2000-11-26 00:00:00...
# Downloading NVDA data from 2000-10-27 00:00:00 to 2001-03-06 00:00:00...
# Downloading NVDA data from 2001-02-04 00:00:00 to 2001-06-14 00:00:00...
# Downloading NVDA data from 2001-05-15 00:00:00 to 2001-09-22 00:00:00...
# Downloading NVDA data from 2001-08-23 00:00:00 to 2001-12-31 00:00:00...
# Downloading NVDA data from 2001-12-01 00:00:00 to 2002-04-10 00:00:00...
# Downloading NVDA data from 2002-03-11 00:00:00 to 2002-07-19 00:00:00...
# Downloading NVDA data from 2002-06-19 00:00:00 to 2002-10-27 00:00:00...
# Downloading NVDA data from 2002-09-27 00:00:00 to 2003-02-04 00:00:00...
# Downloading NVDA data from 2003-01-05 00:00:00 to 2003-05-15 00:00:00...
# Downloading NVDA data from 2003-04-15 00:00:00 to 2003-08-23 00:00:00...
# Downloading NVDA data from 2003-07-24 00:00:00 to 2003-12-01 00:00:00...
# Downloading NVDA data from 2003-11-01 00:00:00 to 2004-03-10 00:00:00...
# Downloading NVDA data from 2004-02-09 00:00:00 to 2004-06-18 00:00:00...
# Downloading NVDA data from 2004-05-19 00:00:00 to 2004-09-26 00:00:00...
# Downloading NVDA data from 2004-08-27 00:00:00 to 2005-01-04 00:00:00...
# Downloading NVDA data from 2004-12-05 00:00:00 to 2005-04-14 00:00:00...
# Downloading NVDA data from 2005-03-15 00:00:00 to 2005-07-23 00:00:00...
# Downloading NVDA data from 2005-06-23 00:00:00 to 2005-10-31 00:00:00...
# Downloading NVDA data from 2005-10-01 00:00:00 to 2006-02-08 00:00:00...
# Downloading NVDA data from 2006-01-09 00:00:00 to 2006-05-19 00:00:00...
# Downloading NVDA data from 2006-04-19 00:00:00 to 2006-08-27 00:00:00...
# Downloading NVDA data from 2006-07-28 00:00:00 to 2006-12-05 00:00:00...
# Downloading NVDA data from 2006-11-05 00:00:00 to 2007-03-15 00:00:00...
# Downloading NVDA data from 2007-02-13 00:00:00 to 2007-06-23 00:00:00...
# Downloading NVDA data from 2007-05-24 00:00:00 to 2007-10-01 00:00:00...
# Downloading NVDA data from 2007-09-01 00:00:00 to 2008-01-09 00:00:00...
# Downloading NVDA data from 2007-12-10 00:00:00 to 2008-04-18 00:00:00...
# Downloading NVDA data from 2008-03-19 00:00:00 to 2008-07-27 00:00:00...
# Downloading NVDA data from 2008-06-27 00:00:00 to 2008-11-04 00:00:00...
# Downloading NVDA data from 2008-10-05 00:00:00 to 2009-02-12 00:00:00...
# Downloading NVDA data from 2009-01-13 00:00:00 to 2009-05-23 00:00:00...
# Downloading NVDA data from 2009-04-23 00:00:00 to 2009-08-31 00:00:00...
# Downloading NVDA data from 2009-08-01 00:00:00 to 2009-12-09 00:00:00...
# Downloading NVDA data from 2009-11-09 00:00:00 to 2010-03-19 00:00:00...
# Downloading NVDA data from 2010-02-17 00:00:00 to 2010-06-27 00:00:00...
# Downloading NVDA data from 2010-05-28 00:00:00 to 2010-10-05 00:00:00...
# Downloading NVDA data from 2010-09-05 00:00:00 to 2011-01-13 00:00:00...
# Downloading NVDA data from 2010-12-14 00:00:00 to 2011-04-23 00:00:00...
# Downloading NVDA data from 2011-03-24 00:00:00 to 2011-08-01 00:00:00...
# Downloading NVDA data from 2011-07-02 00:00:00 to 2011-11-09 00:00:00...
# Downloading NVDA data from 2011-10-10 00:00:00 to 2012-02-17 00:00:00...
# Downloading NVDA data from 2012-01-18 00:00:00 to 2012-05-27 00:00:00...
# Downloading NVDA data from 2012-04-27 00:00:00 to 2012-09-04 00:00:00...
# Downloading NVDA data from 2012-08-05 00:00:00 to 2012-12-13 00:00:00...
# Downloading NVDA data from 2012-11-13 00:00:00 to 2013-03-23 00:00:00...
# Downloading NVDA data from 2013-02-21 00:00:00 to 2013-07-01 00:00:00...
# Downloading NVDA data from 2013-06-01 00:00:00 to 2013-10-09 00:00:00...
# Downloading NVDA data from 2013-09-09 00:00:00 to 2014-01-17 00:00:00...
# Downloading NVDA data from 2013-12-18 00:00:00 to 2014-04-27 00:00:00...
# Saved spectrogram: spectrograms_train/NVDA_Period1.png
# Saved spectrogram: spectrograms_train/NVDA_Period2.png
# Saved spectrogram: spectrograms_train/NVDA_Period3.png
# Saved spectrogram: spectrograms_train/NVDA_Period4.png
# Saved spectrogram: spectrograms_train/NVDA_Period5.png
# Saved spectrogram: spectrograms_train/NVDA_Period6.png
# Saved spectrogram: spectrograms_train/NVDA_Period7.png
# Saved spectrogram: spectrograms_train/NVDA_Period8.png
# Saved spectrogram: spectrograms_train/NVDA_Period9.png
# Saved spectrogram: spectrograms_train/NVDA_Period10.png
# Saved spectrogram: spectrograms_train/NVDA_Period11.png
# Saved spectrogram: spectrograms_train/NVDA_Period12.png
# Saved spectrogram: spectrograms_train/NVDA_Period13.png
# Saved spectrogram: spectrograms_train/NVDA_Period14.png
# Saved spectrogram: spectrograms_train/NVDA_Period15.png
# Saved spectrogram: spectrograms_train/NVDA_Period16.png
# Saved spectrogram: spectrograms_train/NVDA_Period17.png
# Saved spectrogram: spectrograms_train/NVDA_Period18.png
# Saved spectrogram: spectrograms_train/NVDA_Period19.png
# Saved spectrogram: spectrograms_train/NVDA_Period20.png
# Saved spectrogram: spectrograms_train/NVDA_Period21.png
# Saved spectrogram: spectrograms_train/NVDA_Period22.png
# Saved spectrogram: spectrograms_train/NVDA_Period23.png
# Saved spectrogram: spectrograms_train/NVDA_Period24.png
# Saved spectrogram: spectrograms_train/NVDA_Period25.png
# Saved spectrogram: spectrograms_train/NVDA_Period26.png
# Saved spectrogram: spectrograms_train/NVDA_Period27.png
# Saved spectrogram: spectrograms_train/NVDA_Period28.png
# Saved spectrogram: spectrograms_train/NVDA_Period29.png
# Saved spectrogram: spectrograms_train/NVDA_Period30.png
# Saved spectrogram: spectrograms_train/NVDA_Period31.png
# Saved spectrogram: spectrograms_train/NVDA_Period32.png
# Saved spectrogram: spectrograms_train/NVDA_Period33.png
# Saved spectrogram: spectrograms_train/NVDA_Period34.png
# Saved spectrogram: spectrograms_train/NVDA_Period35.png
# Saved spectrogram: spectrograms_train/NVDA_Period36.png
# Saved spectrogram: spectrograms_train/NVDA_Period37.png
# Saved spectrogram: spectrograms_train/NVDA_Period38.png
# Saved spectrogram: spectrograms_train/NVDA_Period39.png
# Saved spectrogram: spectrograms_train/NVDA_Period40.png
# Saved spectrogram: spectrograms_train/NVDA_Period41.png
# Saved spectrogram: spectrograms_train/NVDA_Period42.png
# Saved spectrogram: spectrograms_train/NVDA_Period43.png
# Saved spectrogram: spectrograms_train/NVDA_Period44.png
# Saved spectrogram: spectrograms_train/NVDA_Period45.png
# Saved spectrogram: spectrograms_train/NVDA_Period46.png
# Processing JNJ...
# Downloading JNJ data from 2000-01-01 00:00:00 to 2000-05-10 00:00:00...
# Downloading JNJ data from 2000-04-10 00:00:00 to 2000-08-18 00:00:00...
# Downloading JNJ data from 2000-07-19 00:00:00 to 2000-11-26 00:00:00...
# Downloading JNJ data from 2000-10-27 00:00:00 to 2001-03-06 00:00:00...
# Downloading JNJ data from 2001-02-04 00:00:00 to 2001-06-14 00:00:00...
# Downloading JNJ data from 2001-05-15 00:00:00 to 2001-09-22 00:00:00...
# Downloading JNJ data from 2001-08-23 00:00:00 to 2001-12-31 00:00:00...
# Downloading JNJ data from 2001-12-01 00:00:00 to 2002-04-10 00:00:00...
# Downloading JNJ data from 2002-03-11 00:00:00 to 2002-07-19 00:00:00...
# Downloading JNJ data from 2002-06-19 00:00:00 to 2002-10-27 00:00:00...
# Downloading JNJ data from 2002-09-27 00:00:00 to 2003-02-04 00:00:00...
# Downloading JNJ data from 2003-01-05 00:00:00 to 2003-05-15 00:00:00...
# Downloading JNJ data from 2003-04-15 00:00:00 to 2003-08-23 00:00:00...
# Downloading JNJ data from 2003-07-24 00:00:00 to 2003-12-01 00:00:00...
# Downloading JNJ data from 2003-11-01 00:00:00 to 2004-03-10 00:00:00...
# Downloading JNJ data from 2004-02-09 00:00:00 to 2004-06-18 00:00:00...
# Downloading JNJ data from 2004-05-19 00:00:00 to 2004-09-26 00:00:00...
# Downloading JNJ data from 2004-08-27 00:00:00 to 2005-01-04 00:00:00...
# Downloading JNJ data from 2004-12-05 00:00:00 to 2005-04-14 00:00:00...
# Downloading JNJ data from 2005-03-15 00:00:00 to 2005-07-23 00:00:00...
# Downloading JNJ data from 2005-06-23 00:00:00 to 2005-10-31 00:00:00...
# Downloading JNJ data from 2005-10-01 00:00:00 to 2006-02-08 00:00:00...
# Downloading JNJ data from 2006-01-09 00:00:00 to 2006-05-19 00:00:00...
# Downloading JNJ data from 2006-04-19 00:00:00 to 2006-08-27 00:00:00...
# Downloading JNJ data from 2006-07-28 00:00:00 to 2006-12-05 00:00:00...
# Downloading JNJ data from 2006-11-05 00:00:00 to 2007-03-15 00:00:00...
# Downloading JNJ data from 2007-02-13 00:00:00 to 2007-06-23 00:00:00...
# Downloading JNJ data from 2007-05-24 00:00:00 to 2007-10-01 00:00:00...
# Downloading JNJ data from 2007-09-01 00:00:00 to 2008-01-09 00:00:00...
# Downloading JNJ data from 2007-12-10 00:00:00 to 2008-04-18 00:00:00...
# Downloading JNJ data from 2008-03-19 00:00:00 to 2008-07-27 00:00:00...
# Downloading JNJ data from 2008-06-27 00:00:00 to 2008-11-04 00:00:00...
# Downloading JNJ data from 2008-10-05 00:00:00 to 2009-02-12 00:00:00...
# Downloading JNJ data from 2009-01-13 00:00:00 to 2009-05-23 00:00:00...
# Downloading JNJ data from 2009-04-23 00:00:00 to 2009-08-31 00:00:00...
# Downloading JNJ data from 2009-08-01 00:00:00 to 2009-12-09 00:00:00...
# Downloading JNJ data from 2009-11-09 00:00:00 to 2010-03-19 00:00:00...
# Downloading JNJ data from 2010-02-17 00:00:00 to 2010-06-27 00:00:00...
# Downloading JNJ data from 2010-05-28 00:00:00 to 2010-10-05 00:00:00...
# Downloading JNJ data from 2010-09-05 00:00:00 to 2011-01-13 00:00:00...
# Downloading JNJ data from 2010-12-14 00:00:00 to 2011-04-23 00:00:00...
# Downloading JNJ data from 2011-03-24 00:00:00 to 2011-08-01 00:00:00...
# Downloading JNJ data from 2011-07-02 00:00:00 to 2011-11-09 00:00:00...
# Downloading JNJ data from 2011-10-10 00:00:00 to 2012-02-17 00:00:00...
# Downloading JNJ data from 2012-01-18 00:00:00 to 2012-05-27 00:00:00...
# Downloading JNJ data from 2012-04-27 00:00:00 to 2012-09-04 00:00:00...
# Downloading JNJ data from 2012-08-05 00:00:00 to 2012-12-13 00:00:00...
# Downloading JNJ data from 2012-11-13 00:00:00 to 2013-03-23 00:00:00...
# Downloading JNJ data from 2013-02-21 00:00:00 to 2013-07-01 00:00:00...
# Downloading JNJ data from 2013-06-01 00:00:00 to 2013-10-09 00:00:00...
# Downloading JNJ data from 2013-09-09 00:00:00 to 2014-01-17 00:00:00...
# Downloading JNJ data from 2013-12-18 00:00:00 to 2014-04-27 00:00:00...
# Saved spectrogram: spectrograms_train/JNJ_Period1.png
# Saved spectrogram: spectrograms_train/JNJ_Period2.png
# Saved spectrogram: spectrograms_train/JNJ_Period3.png
# Saved spectrogram: spectrograms_train/JNJ_Period4.png
# Saved spectrogram: spectrograms_train/JNJ_Period5.png
# Saved spectrogram: spectrograms_train/JNJ_Period6.png
# Saved spectrogram: spectrograms_train/JNJ_Period7.png
# Saved spectrogram: spectrograms_train/JNJ_Period8.png
# Saved spectrogram: spectrograms_train/JNJ_Period9.png
# Saved spectrogram: spectrograms_train/JNJ_Period10.png
# Saved spectrogram: spectrograms_train/JNJ_Period11.png
# Saved spectrogram: spectrograms_train/JNJ_Period12.png
# Saved spectrogram: spectrograms_train/JNJ_Period13.png
# Saved spectrogram: spectrograms_train/JNJ_Period14.png
# Saved spectrogram: spectrograms_train/JNJ_Period15.png
# Saved spectrogram: spectrograms_train/JNJ_Period16.png
# Saved spectrogram: spectrograms_train/JNJ_Period17.png
# Saved spectrogram: spectrograms_train/JNJ_Period18.png
# Saved spectrogram: spectrograms_train/JNJ_Period19.png
# Saved spectrogram: spectrograms_train/JNJ_Period20.png
# Saved spectrogram: spectrograms_train/JNJ_Period21.png
# Saved spectrogram: spectrograms_train/JNJ_Period22.png
# Saved spectrogram: spectrograms_train/JNJ_Period23.png
# Saved spectrogram: spectrograms_train/JNJ_Period24.png
# Saved spectrogram: spectrograms_train/JNJ_Period25.png
# Saved spectrogram: spectrograms_train/JNJ_Period26.png
# Saved spectrogram: spectrograms_train/JNJ_Period27.png
# Saved spectrogram: spectrograms_train/JNJ_Period28.png
# Saved spectrogram: spectrograms_train/JNJ_Period29.png
# Saved spectrogram: spectrograms_train/JNJ_Period30.png
# Saved spectrogram: spectrograms_train/JNJ_Period31.png
# Saved spectrogram: spectrograms_train/JNJ_Period32.png
# Saved spectrogram: spectrograms_train/JNJ_Period33.png
# Saved spectrogram: spectrograms_train/JNJ_Period34.png
# Saved spectrogram: spectrograms_train/JNJ_Period35.png
# Saved spectrogram: spectrograms_train/JNJ_Period36.png
# Saved spectrogram: spectrograms_train/JNJ_Period37.png
# Saved spectrogram: spectrograms_train/JNJ_Period38.png
# Saved spectrogram: spectrograms_train/JNJ_Period39.png
# Saved spectrogram: spectrograms_train/JNJ_Period40.png
# Saved spectrogram: spectrograms_train/JNJ_Period41.png
# Saved spectrogram: spectrograms_train/JNJ_Period42.png
# Saved spectrogram: spectrograms_train/JNJ_Period43.png
# Saved spectrogram: spectrograms_train/JNJ_Period44.png
# Saved spectrogram: spectrograms_train/JNJ_Period45.png
# Saved spectrogram: spectrograms_train/JNJ_Period46.png
# Processing JPM...
# Downloading JPM data from 2000-01-01 00:00:00 to 2000-05-10 00:00:00...
# Downloading JPM data from 2000-04-10 00:00:00 to 2000-08-18 00:00:00...
# Downloading JPM data from 2000-07-19 00:00:00 to 2000-11-26 00:00:00...
# Downloading JPM data from 2000-10-27 00:00:00 to 2001-03-06 00:00:00...
# ...
# Downloading UNH data from 2003-04-15 00:00:00 to 2003-08-23 00:00:00...
# Downloading UNH data from 2003-07-24 00:00:00 to 2003-12-01 00:00:00...
# Downloading UNH data from 2003-11-01 00:00:00 to 2004-03-10 00:00:00...
# Downloading UNH data from 2004-02-09 00:00:00 to 2004-06-18 00:00:00...
# Downloading UNH data from 2004-05-19 00:00:00 to 2004-09-26 00:00:00...
# Downloading UNH data from 2004-08-27 00:00:00 to 2005-01-04 00:00:00...
# Downloading UNH data from 2004-12-05 00:00:00 to 2005-04-14 00:00:00...
# Downloading UNH data from 2005-03-15 00:00:00 to 2005-07-23 00:00:00...
# Downloading UNH data from 2005-06-23 00:00:00 to 2005-10-31 00:00:00...
# Downloading UNH data from 2005-10-01 00:00:00 to 2006-02-08 00:00:00...
# Downloading UNH data from 2006-01-09 00:00:00 to 2006-05-19 00:00:00...
# Downloading UNH data from 2006-04-19 00:00:00 to 2006-08-27 00:00:00...
# Downloading UNH data from 2006-07-28 00:00:00 to 2006-12-05 00:00:00...
# Downloading UNH data from 2006-11-05 00:00:00 to 2007-03-15 00:00:00...
# Downloading UNH data from 2007-02-13 00:00:00 to 2007-06-23 00:00:00...
# Downloading UNH data from 2007-05-24 00:00:00 to 2007-10-01 00:00:00...
# Downloading UNH data from 2007-09-01 00:00:00 to 2008-01-09 00:00:00...
# Downloading UNH data from 2007-12-10 00:00:00 to 2008-04-18 00:00:00...
# Downloading UNH data from 2008-03-19 00:00:00 to 2008-07-27 00:00:00...
# Downloading UNH data from 2008-06-27 00:00:00 to 2008-11-04 00:00:00...
# Downloading UNH data from 2008-10-05 00:00:00 to 2009-02-12 00:00:00...
# Downloading UNH data from 2009-01-13 00:00:00 to 2009-05-23 00:00:00...
# Downloading UNH data from 2009-04-23 00:00:00 to 2009-08-31 00:00:00...
# Downloading UNH data from 2009-08-01 00:00:00 to 2009-12-09 00:00:00...
# Downloading UNH data from 2009-11-09 00:00:00 to 2010-03-19 00:00:00...
# Downloading UNH data from 2010-02-17 00:00:00 to 2010-06-27 00:00:00...
# Downloading UNH data from 2010-05-28 00:00:00 to 2010-10-05 00:00:00...
# Downloading UNH data from 2010-09-05 00:00:00 to 2011-01-13 00:00:00...
# Downloading UNH data from 2010-12-14 00:00:00 to 2011-04-23 00:00:00...
# Downloading UNH data from 2011-03-24 00:00:00 to 2011-08-01 00:00:00...
# Downloading UNH data from 2011-07-02 00:00:00 to 2011-11-09 00:00:00...
# Downloading UNH data from 2011-10-10 00:00:00 to 2012-02-17 00:00:00...
# Downloading UNH data from 2012-01-18 00:00:00 to 2012-05-27 00:00:00...
# Downloading UNH data from 2012-04-27 00:00:00 to 2012-09-04 00:00:00...
# Downloading UNH data from 2012-08-05 00:00:00 to 2012-12-13 00:00:00...
# Downloading UNH data from 2012-11-13 00:00:00 to 2013-03-23 00:00:00...
# Downloading UNH data from 2013-02-21 00:00:00 to 2013-07-01 00:00:00...
# Downloading UNH data from 2013-06-01 00:00:00 to 2013-10-09 00:00:00...
# Downloading UNH data from 2013-09-09 00:00:00 to 2014-01-17 00:00:00...
# Downloading UNH data from 2013-12-18 00:00:00 to 2014-04-27 00:00:00...
# Saved spectrogram: spectrograms_train/UNH_Period1.png
# Saved spectrogram: spectrograms_train/UNH_Period2.png
# Saved spectrogram: spectrograms_train/UNH_Period3.png
# Saved spectrogram: spectrograms_train/UNH_Period4.png
# Saved spectrogram: spectrograms_train/UNH_Period5.png
# Saved spectrogram: spectrograms_train/UNH_Period6.png
# Saved spectrogram: spectrograms_train/UNH_Period7.png
# Saved spectrogram: spectrograms_train/UNH_Period8.png
# Saved spectrogram: spectrograms_train/UNH_Period9.png
# Saved spectrogram: spectrograms_train/UNH_Period10.png
# Saved spectrogram: spectrograms_train/UNH_Period11.png
# Saved spectrogram: spectrograms_train/UNH_Period12.png
# Saved spectrogram: spectrograms_train/UNH_Period13.png
# Saved spectrogram: spectrograms_train/UNH_Period14.png
# Saved spectrogram: spectrograms_train/UNH_Period15.png
# Saved spectrogram: spectrograms_train/UNH_Period16.png
# Saved spectrogram: spectrograms_train/UNH_Period17.png
# Saved spectrogram: spectrograms_train/UNH_Period18.png
# Saved spectrogram: spectrograms_train/UNH_Period19.png
# Saved spectrogram: spectrograms_train/UNH_Period20.png
# Saved spectrogram: spectrograms_train/UNH_Period21.png
# Saved spectrogram: spectrograms_train/UNH_Period22.png
# Saved spectrogram: spectrograms_train/UNH_Period23.png
# Saved spectrogram: spectrograms_train/UNH_Period24.png
# Saved spectrogram: spectrograms_train/UNH_Period25.png
# Saved spectrogram: spectrograms_train/UNH_Period26.png
# Saved spectrogram: spectrograms_train/UNH_Period27.png
# Saved spectrogram: spectrograms_train/UNH_Period28.png
# Saved spectrogram: spectrograms_train/UNH_Period29.png
# Saved spectrogram: spectrograms_train/UNH_Period30.png
# Saved spectrogram: spectrograms_train/UNH_Period31.png
# Saved spectrogram: spectrograms_train/UNH_Period32.png
# Saved spectrogram: spectrograms_train/UNH_Period33.png
# Saved spectrogram: spectrograms_train/UNH_Period34.png
# Saved spectrogram: spectrograms_train/UNH_Period35.png
# Saved spectrogram: spectrograms_train/UNH_Period36.png
# Saved spectrogram: spectrograms_train/UNH_Period37.png
# Saved spectrogram: spectrograms_train/UNH_Period38.png
# Saved spectrogram: spectrograms_train/UNH_Period39.png
# Saved spectrogram: spectrograms_train/UNH_Period40.png
# Saved spectrogram: spectrograms_train/UNH_Period41.png
# Saved spectrogram: spectrograms_train/UNH_Period42.png
# Saved spectrogram: spectrograms_train/UNH_Period43.png
# Saved spectrogram: spectrograms_train/UNH_Period44.png
# Saved spectrogram: spectrograms_train/UNH_Period45.png
# Saved spectrogram: spectrograms_train/UNH_Period46.png
# Processing HD...
# Downloading HD data from 2000-01-01 00:00:00 to 2000-05-10 00:00:00...
# Downloading HD data from 2000-04-10 00:00:00 to 2000-08-18 00:00:00...
# Downloading HD data from 2000-07-19 00:00:00 to 2000-11-26 00:00:00...
# Downloading HD data from 2000-10-27 00:00:00 to 2001-03-06 00:00:00...
# Downloading HD data from 2001-02-04 00:00:00 to 2001-06-14 00:00:00...
# Downloading HD data from 2001-05-15 00:00:00 to 2001-09-22 00:00:00...
# Downloading HD data from 2001-08-23 00:00:00 to 2001-12-31 00:00:00...
# Downloading HD data from 2001-12-01 00:00:00 to 2002-04-10 00:00:00...
# Downloading HD data from 2002-03-11 00:00:00 to 2002-07-19 00:00:00...
# Downloading HD data from 2002-06-19 00:00:00 to 2002-10-27 00:00:00...
# Downloading HD data from 2002-09-27 00:00:00 to 2003-02-04 00:00:00...
# Downloading HD data from 2003-01-05 00:00:00 to 2003-05-15 00:00:00...
# Downloading HD data from 2003-04-15 00:00:00 to 2003-08-23 00:00:00...
# Downloading HD data from 2003-07-24 00:00:00 to 2003-12-01 00:00:00...
# Downloading HD data from 2003-11-01 00:00:00 to 2004-03-10 00:00:00...
# Downloading HD data from 2004-02-09 00:00:00 to 2004-06-18 00:00:00...
# Downloading HD data from 2004-05-19 00:00:00 to 2004-09-26 00:00:00...
# Downloading HD data from 2004-08-27 00:00:00 to 2005-01-04 00:00:00...
# Downloading HD data from 2004-12-05 00:00:00 to 2005-04-14 00:00:00...
# Downloading HD data from 2005-03-15 00:00:00 to 2005-07-23 00:00:00...
# Downloading HD data from 2005-06-23 00:00:00 to 2005-10-31 00:00:00...
# Downloading HD data from 2005-10-01 00:00:00 to 2006-02-08 00:00:00...
# Downloading HD data from 2006-01-09 00:00:00 to 2006-05-19 00:00:00...
# Downloading HD data from 2006-04-19 00:00:00 to 2006-08-27 00:00:00...
# Downloading HD data from 2006-07-28 00:00:00 to 2006-12-05 00:00:00...
# Downloading HD data from 2006-11-05 00:00:00 to 2007-03-15 00:00:00...
# Downloading HD data from 2007-02-13 00:00:00 to 2007-06-23 00:00:00...
# Downloading HD data from 2007-05-24 00:00:00 to 2007-10-01 00:00:00...
# Downloading HD data from 2007-09-01 00:00:00 to 2008-01-09 00:00:00...
# Downloading HD data from 2007-12-10 00:00:00 to 2008-04-18 00:00:00...
# Downloading HD data from 2008-03-19 00:00:00 to 2008-07-27 00:00:00...
# Downloading HD data from 2008-06-27 00:00:00 to 2008-11-04 00:00:00...
# Downloading HD data from 2008-10-05 00:00:00 to 2009-02-12 00:00:00...
# Downloading HD data from 2009-01-13 00:00:00 to 2009-05-23 00:00:00...
# Downloading HD data from 2009-04-23 00:00:00 to 2009-08-31 00:00:00...
# Downloading HD data from 2009-08-01 00:00:00 to 2009-12-09 00:00:00...
# Downloading HD data from 2009-11-09 00:00:00 to 2010-03-19 00:00:00...
# Downloading HD data from 2010-02-17 00:00:00 to 2010-06-27 00:00:00...
# Downloading HD data from 2010-05-28 00:00:00 to 2010-10-05 00:00:00...
# Downloading HD data from 2010-09-05 00:00:00 to 2011-01-13 00:00:00...
# Downloading HD data from 2010-12-14 00:00:00 to 2011-04-23 00:00:00...
# Downloading HD data from 2011-03-24 00:00:00 to 2011-08-01 00:00:00...
# Downloading HD data from 2011-07-02 00:00:00 to 2011-11-09 00:00:00...
# Downloading HD data from 2011-10-10 00:00:00 to 2012-02-17 00:00:00...
# Downloading HD data from 2012-01-18 00:00:00 to 2012-05-27 00:00:00...
# Downloading HD data from 2012-04-27 00:00:00 to 2012-09-04 00:00:00...
# Downloading HD data from 2012-08-05 00:00:00 to 2012-12-13 00:00:00...
# Downloading HD data from 2012-11-13 00:00:00 to 2013-03-23 00:00:00...
# Downloading HD data from 2013-02-21 00:00:00 to 2013-07-01 00:00:00...
# Downloading HD data from 2013-06-01 00:00:00 to 2013-10-09 00:00:00...
# Downloading HD data from 2013-09-09 00:00:00 to 2014-01-17 00:00:00...
# Downloading HD data from 2013-12-18 00:00:00 to 2014-04-27 00:00:00...
# Saved spectrogram: spectrograms_train/HD_Period1.png
# Saved spectrogram: spectrograms_train/HD_Period2.png
# Saved spectrogram: spectrograms_train/HD_Period3.png
# Saved spectrogram: spectrograms_train/HD_Period4.png
# Saved spectrogram: spectrograms_train/HD_Period5.png
# Saved spectrogram: spectrograms_train/HD_Period6.png
# Saved spectrogram: spectrograms_train/HD_Period7.png
# Saved spectrogram: spectrograms_train/HD_Period8.png
# Saved spectrogram: spectrograms_train/HD_Period9.png
# Saved spectrogram: spectrograms_train/HD_Period10.png
# Saved spectrogram: spectrograms_train/HD_Period11.png
# Saved spectrogram: spectrograms_train/HD_Period12.png
# Saved spectrogram: spectrograms_train/HD_Period13.png
# Saved spectrogram: spectrograms_train/HD_Period14.png
# Saved spectrogram: spectrograms_train/HD_Period15.png
# Saved spectrogram: spectrograms_train/HD_Period16.png
# Saved spectrogram: spectrograms_train/HD_Period17.png
# Saved spectrogram: spectrograms_train/HD_Period18.png
# Saved spectrogram: spectrograms_train/HD_Period19.png
# Saved spectrogram: spectrograms_train/HD_Period20.png
# Saved spectrogram: spectrograms_train/HD_Period21.png
# Saved spectrogram: spectrograms_train/HD_Period22.png
# Saved spectrogram: spectrograms_train/HD_Period23.png
# Saved spectrogram: spectrograms_train/HD_Period24.png
# Saved spectrogram: spectrograms_train/HD_Period25.png
# Saved spectrogram: spectrograms_train/HD_Period26.png
# Saved spectrogram: spectrograms_train/HD_Period27.png
# Saved spectrogram: spectrograms_train/HD_Period28.png
# Saved spectrogram: spectrograms_train/HD_Period29.png
# Saved spectrogram: spectrograms_train/HD_Period30.png
# Saved spectrogram: spectrograms_train/HD_Period31.png
# Saved spectrogram: spectrograms_train/HD_Period32.png
# Saved spectrogram: spectrograms_train/HD_Period33.png
# Saved spectrogram: spectrograms_train/HD_Period34.png
# Saved spectrogram: spectrograms_train/HD_Period35.png
# Saved spectrogram: spectrograms_train/HD_Period36.png
# Saved spectrogram: spectrograms_train/HD_Period37.png
# Saved spectrogram: spectrograms_train/HD_Period38.png
# Saved spectrogram: spectrograms_train/HD_Period39.png
# Saved spectrogram: spectrograms_train/HD_Period40.png
# Saved spectrogram: spectrograms_train/HD_Period41.png
# Saved spectrogram: spectrograms_train/HD_Period42.png
# Saved spectrogram: spectrograms_train/HD_Period43.png
# Saved spectrogram: spectrograms_train/HD_Period44.png
# Saved spectrogram: spectrograms_train/HD_Period45.png
# Saved spectrogram: spectrograms_train/HD_Period46.png
# Processing MA...
# Downloading MA data from 2000-01-01 00:00:00 to 2000-05-10 00:00:00...
# 1 Failed download:
# ['MA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2000-01-01 00:00:00 -> 2000-05-10 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 946702800, endDate = 957931200")')
# Downloading MA data from 2000-04-10 00:00:00 to 2000-08-18 00:00:00...
# 1 Failed download:
# ['MA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2000-04-10 00:00:00 -> 2000-08-18 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 955339200, endDate = 966571200")')
# Downloading MA data from 2000-07-19 00:00:00 to 2000-11-26 00:00:00...
# 1 Failed download:
# ['MA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2000-07-19 00:00:00 -> 2000-11-26 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 963979200, endDate = 975214800")')
# Downloading MA data from 2000-10-27 00:00:00 to 2001-03-06 00:00:00...
# 1 Failed download:
# ['MA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2000-10-27 00:00:00 -> 2001-03-06 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 972619200, endDate = 983854800")')
# Downloading MA data from 2001-02-04 00:00:00 to 2001-06-14 00:00:00...
# 1 Failed download:
# ['MA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2001-02-04 00:00:00 -> 2001-06-14 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 981262800, endDate = 992491200")')
# Downloading MA data from 2001-05-15 00:00:00 to 2001-09-22 00:00:00...
# 1 Failed download:
# ['MA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2001-05-15 00:00:00 -> 2001-09-22 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 989899200, endDate = 1001131200")')
# Downloading MA data from 2001-08-23 00:00:00 to 2001-12-31 00:00:00...
# 1 Failed download:
# ['MA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2001-08-23 00:00:00 -> 2001-12-31 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 998539200, endDate = 1009774800")')
# Downloading MA data from 2001-12-01 00:00:00 to 2002-04-10 00:00:00...
# 1 Failed download:
# ['MA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2001-12-01 00:00:00 -> 2002-04-10 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1007182800, endDate = 1018411200")')
# Downloading MA data from 2002-03-11 00:00:00 to 2002-07-19 00:00:00...
# 1 Failed download:
# ['MA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2002-03-11 00:00:00 -> 2002-07-19 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1015822800, endDate = 1027051200")')
# Downloading MA data from 2002-06-19 00:00:00 to 2002-10-27 00:00:00...
# 1 Failed download:
# ['MA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2002-06-19 00:00:00 -> 2002-10-27 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1024459200, endDate = 1035691200")')
# Downloading MA data from 2002-09-27 00:00:00 to 2003-02-04 00:00:00...
# 1 Failed download:
# ['MA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2002-09-27 00:00:00 -> 2003-02-04 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1033099200, endDate = 1044334800")')
# Downloading MA data from 2003-01-05 00:00:00 to 2003-05-15 00:00:00...
# 1 Failed download:
# ['MA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2003-01-05 00:00:00 -> 2003-05-15 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1041742800, endDate = 1052971200")')
# Downloading MA data from 2003-04-15 00:00:00 to 2003-08-23 00:00:00...
# 1 Failed download:
# ['MA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2003-04-15 00:00:00 -> 2003-08-23 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1050379200, endDate = 1061611200")')
# Downloading MA data from 2003-07-24 00:00:00 to 2003-12-01 00:00:00...
# 1 Failed download:
# ['MA']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2003-07-24 00:00:00 -> 2003-12-01 00:00:00) (Yahoo error = "Data doesn\'t exist for startDate = 1059019200, endDate = 1070254800")')
# Downloading MA data from 2003-11-01 00:00:00 to 2004-03-10 00:00:00...

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import pywt
import pandas as pd
import os
from datetime import datetime, timedelta

# Step 1: Create Directory to Save Images and Labels
output_dir = "spectrograms_test"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

label_file = os.path.join(output_dir, "labels.csv")

# Step 2: Download Stock Data with Extended Periods
def download_data_with_extension(ticker, start_date, end_date, chunk_size_days, extension_days):
    """
    Download time series data for a given ticker, including an extension for future trend analysis.
    """
    current_date = start_date
    all_data = []

    while current_date < end_date:
        next_date = current_date + timedelta(days=chunk_size_days + extension_days)
        print(f"Downloading {ticker} data from {current_date} to {next_date}...")
        
        data = yf.download(ticker, start=current_date, end=next_date, progress=False)
        if not data.empty:
            all_data.append(data['Close'])
        
        current_date = current_date + timedelta(days=chunk_size_days)

    return pd.concat(all_data, axis=0)

# Step 3: Compute Future Trend Label
def compute_future_trend_label(future_period_prices, threshold=0.005):
    """
    Compute label based on the average price variation between current and future periods:
        1 -> Positive trend (average price increase > threshold)
        0 -> Neutral trend (within ±threshold)
       -1 -> Negative trend (average price decrease > threshold)
    """
    if len(future_period_prices) == 0:
        return None
    
    price_change = (future_period_prices[-1]-future_period_prices[0])/future_period_prices[0]

    if price_change > threshold:
        return 1  # Upwards trend
    elif price_change < -threshold:
        return -1  # Downwards trend
    else:
        return 0  # Neutral trend

# Step 4: Generate Wavelet Spectrogram and Save Image
def generate_wavelet_spectrogram(signal, stock_name, period_num, wavelet='morl', scales=None):
    """
    Generate and save a spectrogram image using Continuous Wavelet Transform (CWT).
    """
    if scales is None:
        scales = np.arange(1, 128)

    # Perform Continuous Wavelet Transform
    coefficients, frequencies = pywt.cwt(signal, scales, wavelet)
    
    # Plot the spectrogram
    plt.figure(figsize=(10, 6))
    plt.imshow(np.abs(coefficients), extent=[0, len(signal), 1, 128],
               interpolation='bilinear', aspect='auto', cmap='jet')
    plt.colorbar(label='Power')
    plt.ylabel('Frequency (Scale)')
    plt.xlabel('Time')
    plt.title(f'{stock_name} - Period {period_num} Spectrogram')

    # Save the image
    image_path = os.path.join(output_dir, f"{stock_name}_Period{period_num}.png")
    plt.savefig(image_path)
    plt.close()
    print(f"Saved spectrogram: {image_path}")

    return image_path


# Step 5: Process Stocks and Save Labels
def process_stocks(tickers, start_date, end_date, chunk_size_days=100, extension_days=30, threshold=0.005):
    """
    Download stock data, generate spectrograms, and assign labels based on future trends.
    """
    labels = []

    for ticker in tickers:
        print(f"Processing {ticker}...")
        try:
            # Download data with extension for future trend analysis
            close_prices = download_data_with_extension(ticker, start_date, end_date, chunk_size_days, extension_days)
            close_prices = close_prices.dropna()
            
            if len(close_prices) == 0:
                print(f"No valid data for {ticker}. Skipping...")
                continue
            
            # Process each 100-day period
            period_num = 1
            for i in range(0, len(close_prices) - chunk_size_days - extension_days + 1, chunk_size_days):
                current_chunk = close_prices.iloc[i:i + chunk_size_days].values
                future_chunk = close_prices.iloc[i + chunk_size_days:i + chunk_size_days + extension_days].values
                
                if len(current_chunk) < 2 or len(future_chunk) < 2:
                    continue
                
                # Compute label based on future trend
                label = compute_future_trend_label( future_chunk, threshold)
                if label is None:
                    continue
                
                # Generate and save spectrogram
                image_path = generate_wavelet_spectrogram(current_chunk, ticker, period_num)
                
                # Append to labels list
                labels.append([image_path, label])
                period_num += 1
                
        except Exception as e:
            print(f"Error processing {ticker}: {e}")

    # Save labels to CSV
    labels_df = pd.DataFrame(labels, columns=["image_path", "label"])
    labels_df.to_csv(label_file, index=False)
    print(f"Labels saved to {label_file}")


# Step 6: Main Execution
if __name__ == "__main__":
    # List of Stocks (First 10 for demonstration)
    tickers = [ "AAPL", "MSFT", "AMZN", "GOOG", "BRK-B", "NVDA", "JNJ", "JPM", "PG", "UNH", "HD", "MA", "DIS", "NFLX", "KO", "PEP",
    "CSCO", "XOM", "PFE", "MRK", "INTC", "BA", "WMT", "MCD", "IBM", "GS",
    "NKE", "ADBE", "HON", "AMGN", "T", "COST", "ABT", "LMT", "BMY", "CAT",
    "DHR", "MDT", "CVX", "ORCL", "CMCSA", "MS", "ISRG", "TXN", "UNP", "QCOM",
    "LIN", "PM", "SBUX", "AMAT", "MMM", "NEE", "BLK", "SPGI", "NOW", "GE",
    "LLY", "ZTS", "LOW", "TGT", "INTU", "ANTM", "MU", "FIS", "CSX", "VRTX",
    "GILD", "APD", "PLD", "ADI", "C", "DUK", "SYK", "USB", "SO", "SCHW",
    "MMC", "CL", "TJX", "BDX", "CI", "PNC", "CME", "NSC", "EW", "ETN",
    "ADI", "ROP", "FCX", "ICE", "TRV", "TMO", "GM", "AON", "FDX", "HUM"]
    
    # Define Date Range (2007 to 2017)
    start_date = datetime(2016, 1, 1)
    end_date = datetime(2019, 1, 1)
    
    # Process Stocks and Generate Spectrograms with Labels
    process_stocks(tickers, start_date, end_date)
# Out:
# Processing AAPL...
# Downloading AAPL data from 2016-01-01 00:00:00 to 2016-05-10 00:00:00...
# Downloading AAPL data from 2016-04-10 00:00:00 to 2016-08-18 00:00:00...
# Downloading AAPL data from 2016-07-19 00:00:00 to 2016-11-26 00:00:00...
# Downloading AAPL data from 2016-10-27 00:00:00 to 2017-03-06 00:00:00...
# Downloading AAPL data from 2017-02-04 00:00:00 to 2017-06-14 00:00:00...
# Downloading AAPL data from 2017-05-15 00:00:00 to 2017-09-22 00:00:00...
# Downloading AAPL data from 2017-08-23 00:00:00 to 2017-12-31 00:00:00...
# Downloading AAPL data from 2017-12-01 00:00:00 to 2018-04-10 00:00:00...
# Downloading AAPL data from 2018-03-11 00:00:00 to 2018-07-19 00:00:00...
# Downloading AAPL data from 2018-06-19 00:00:00 to 2018-10-27 00:00:00...
# Downloading AAPL data from 2018-09-27 00:00:00 to 2019-02-04 00:00:00...
# Saved spectrogram: spectrograms_test/AAPL_Period1.png
# Saved spectrogram: spectrograms_test/AAPL_Period2.png
# Saved spectrogram: spectrograms_test/AAPL_Period3.png
# Saved spectrogram: spectrograms_test/AAPL_Period4.png
# Saved spectrogram: spectrograms_test/AAPL_Period5.png
# Saved spectrogram: spectrograms_test/AAPL_Period6.png
# Saved spectrogram: spectrograms_test/AAPL_Period7.png
# Saved spectrogram: spectrograms_test/AAPL_Period8.png
# Saved spectrogram: spectrograms_test/AAPL_Period9.png
# Labels saved to spectrograms_test/labels.csv
